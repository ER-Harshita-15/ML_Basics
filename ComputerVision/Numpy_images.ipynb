# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img= Image.open('ML.jfif')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=281x179>

# %%
img2=Image.open('SL vs USL.png')
img2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=701x591>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
type(img2)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
print(img.mode)
print(img2.mode)
# Out:
# RGB
# RGBA

# %%
img_array=np.array(img)
print(img_array)
print(img_array.shape)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# (179, 281, 3)

# %%
img_array2=np.array(img2)
print(img_array2)
print(img_array2.shape)
# Out:
# [[[ 91  91  90 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  [[ 91  91  90 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  [[ 91  91  90 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  ...
#
#  [[ 97  96  95 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  [[ 97  96  95 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  [[ 97  96  95 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]]
# (591, 701, 4)

# %%
plt.imshow(img_array)

# %%
img1=img_array.copy()
img3=img_array.copy()
img4=img_array.copy()

# %%
img1[:,:,0]
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], shape=(179, 281), dtype=uint8)

# %%
img1[:,:,0]=0  # Set red channel to 0 i.e. remove red color
plt.imshow(img1)

# %%
img3[:,:,1]
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], shape=(179, 281), dtype=uint8)

# %%
img3[:,:,1]=0  # Set green channel to 0 i.e. remove green color
plt.imshow(img3)

# %%
img4[:,:,2]
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], shape=(179, 281), dtype=uint8)

# %%
img4[:,:,2]=0  # Set blue channel to 0 i.e. remove blue color
plt.imshow(img4)

# %% [markdown]
# This proves that a perfect balance of RGB creates an image perfectly colourful

# %%
img_array[:,:,0]=0
img_array[:,:,1]=0
img_array[:,:,2]=0
plt.imshow(img_array)

# %% [markdown]
# As all the colours(RGB) are removed hence there is no colour in pixels

# %%
img5=img_array2.copy()

# %%
img5[:,:,0]=255 
plt.imshow(img5)

# %%
img5[:,:,1]=255 
plt.imshow(img5)

# %%
img5[:,:,0]=255 
plt.imshow(img5)

# %% [markdown]
# So if RGB=0 then the image turns black and if RGB=255 then the image turns white

# %%
img5[:,:,0]=40
img5[:,:,1]=78
img5[:,:,2]=156
plt.imshow(img5)

# %%
img_array2[:,:,0]=40
img_array2[:,:,1]=78
img_array2[:,:,2]=156

# %%
img_array2   #Directly changing the pixel values of the image array  hence the image is changed  therefore we create a copy of the image array to avoid changing the original image to make changes in it
# Out:
# array([[[ 40,  78, 156, 255],
#         [ 40,  78, 156, 255],
#         [ 40,  78, 156, 255],
#         ...,
#         [ 40,  78, 156, 255],
#         [ 40,  78, 156, 255],
#         [ 40,  78, 156, 255]],
#
#        [[ 40,  78, 156, 255],
#         [ 40,  78, 156, 255],
#         [ 40,  78, 156, 255],
#         ...,
#         [ 40,  78, 156, 255],
#         [ 40,  78, 156, 255],
#         [ 40,  78, 156, 255]],
#
#        [[ 40,  78, 156, 255],
#         [ 40,  78, 156, 255],
#         [ 40,  78, 156, 255],
#         ...,
#         [ 40,  78, 156, 255],
#         [ 40,  78, 156, 255],
#         [ 40,  78, 156, 255]],
#
#        ...,
#
#        [[ 40,  78, 156, 255],
#         [ 40,  78, 156, 255],
#         [ 40,  78, 156, 255],
#         ...,
#         [ 40,  78, 156, 255],
#         [ 40,  78, 156, 255],
#         [ 40,  78, 156, 255]],
#
#        [[ 40,  78, 156, 255],
#         [ 40,  78, 156, 255],
#         [ 40,  78, 156, 255],
#         ...,
#         [ 40,  78, 156, 255],
# ...

# %%
plt.imshow(img_array2)

# %% [markdown]
# Hence you can again and again create array and destort it or you can create copies of experimenting keeping the original array of the image safe.
